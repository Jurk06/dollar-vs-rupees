# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import plotly.plotly as py
import plotly.tools as tls
import plotly.graph_objs as go
sns.set_style(style='darkgrid')

# %%
df=pd.read_csv('C:\\Users\\rabis\\Downloads\\EXINUS.csv')

# %%
df.shape
# Out:
# (549, 2)

# %%
tls.set_credentials_file(username='Jurk06')

# %%
plt.figure(figsize=(15, 4))
plt.title("Dollar Vs Rupess")
plt.scatter(df.DATE, df.EXINUS)
plt.xlabel("Dated")
plt.ylabel("1$= Rs")
plt.plot(df.DATE, df.EXINUS)
plt.show()

# %%
x=df.iloc[:12]

# %%
x.EXINUS.mean()
# Out:
# 7.658466666666668

# %%
plt.figure(figsize=(15,5))
plt.title("Dollar Vs Rupess in year 1973")
plt.scatter(x.DATE, x.EXINUS, marker='v', linestyle='-', linewidths=10, color='red')
plt.plot(x.DATE, x.EXINUS)
plt.xlabel("date")
plt.ylabel("1$= Rs")
plt.show()

# %%
x=df.iloc[12:24]

# %%
plt.figure(figsize=(15, 5))
plt.title("Dollar Vs Rupess in year 1974")
plt.scatter(x.DATE, x.EXINUS, marker='v', color='red', linewidths=10)
plt.plot(x.DATE, x.EXINUS)
plt.xlabel("Dated")
plt.ylabel("1$= Rs")
plt.plot()
plt.show()

# %%
x=df.iloc[24:36]

# %%
plt.figure(figsize=(15, 5))
plt.title("Dollar Vs Rupess in year 1975")
plt.scatter(x.DATE, x.EXINUS, marker='v', color='red', linewidths=10)
plt.plot(x.DATE, x.EXINUS)
plt.xlabel("Dated")
plt.ylabel("1$= Rs")
plt.plot()
plt.show()

# %%
x=df.iloc[36:48]

# %%
x
# Out:
#           DATE  EXINUS
# 36  1976-01-01  8.9471
# 37  1976-02-01  8.9389
# 38  1976-03-01  8.9648
# 39  1976-04-01  8.9918
# 40  1976-05-01  9.0265
# 41  1976-06-01  9.1109
# 42  1976-07-01  8.9233
# 43  1976-08-01  8.9755
# 44  1976-09-01  9.0614
# 45  1976-10-01  8.8960
# 46  1976-11-01  8.9658
# 47  1976-12-01  8.8535

# %%
plt.figure(figsize=(15, 5))
plt.title("Dollar Vs Rupess in year 1976")
plt.scatter(x.DATE, x.EXINUS, marker='v', color='red', linewidths=10)
plt.plot(x.DATE, x.EXINUS)
plt.xlabel("Dated")
plt.ylabel("1$= Rs")
plt.plot()
plt.show()

# %%
x=df.iloc[48:60]

# %%
x
# Out:
#           DATE  EXINUS
# 48  1977-01-01  8.9052
# 49  1977-02-01  8.8626
# 50  1977-03-01  8.8417
# 51  1977-04-01  8.8429
# 52  1977-05-01  8.8338
# 53  1977-06-01  8.8605
# 54  1977-07-01  8.8163
# 55  1977-08-01  8.7213
# 56  1977-09-01  8.7300
# 57  1977-10-01  8.6150
# 58  1977-11-01  8.6405
# 59  1977-12-01  8.5371

# %%
plt.figure(figsize=(15, 5))
plt.title("Dollar Vs Rupess in year 1977")
plt.scatter(x.DATE, x.EXINUS, marker='v', color='red', linewidths=10)
plt.plot(x.DATE, x.EXINUS)
plt.xlabel("Dated")
plt.ylabel("1$= Rs")
plt.plot()
plt.show()

# %%
x=df.iloc[60:72]

# %%
x
# Out:
#           DATE  EXINUS
# 60  1978-01-01  8.2010
# 61  1978-02-01  8.1094
# 62  1978-03-01  8.2078
# 63  1978-04-01  8.4650
# 64  1978-05-01  8.5827
# 65  1978-06-01  8.4041
# 66  1978-07-01  8.1665
# 67  1978-08-01  8.0139
# 68  1978-09-01  8.0365
# 69  1978-10-01  7.9110
# 70  1978-11-01  8.0335
# 71  1978-12-01  8.2160

# %%
plt.figure(figsize=(15, 5))
plt.title("Dollar Vs Rupess in year 1978")
plt.scatter(x.DATE, x.EXINUS, marker='v', color='red', linewidths=10)
plt.plot(x.DATE, x.EXINUS)
plt.xlabel("Dated")
plt.ylabel("1$= Rs")
plt.plot()
plt.show()

# %%
x=df.iloc[72:84]

# %%
x
# Out:
#           DATE  EXINUS
# 72  1979-01-01  8.2091
# 73  1979-02-01  8.2500
# 74  1979-03-01  8.2418
# 75  1979-04-01  8.2062
# 76  1979-05-01  8.2891
# 77  1979-06-01  8.1190
# 78  1979-07-01  7.9067
# 79  1979-08-01  8.0113
# 80  1979-09-01  8.1358
# 81  1979-10-01  8.2259
# 82  1979-11-01  8.1926
# 83  1979-12-01  8.0995

# %%
plt.figure(figsize=(15, 5))
plt.title("Dollar Vs Rupess in year 1979")
plt.scatter(x.DATE, x.EXINUS, marker='v', color='red', linewidths=10)
plt.plot(x.DATE, x.EXINUS)
plt.xlabel("Dated")
plt.ylabel("1$= Rs")
plt.plot()
plt.show()

# %%
x=df.iloc[84:96]

# %%
x
# Out:
#           DATE  EXINUS
# 84  1980-01-01  7.9882
# 85  1980-02-01  7.9816
# 86  1980-03-01  8.1519
# 87  1980-04-01  8.0700
# 88  1980-05-01  7.8586
# 89  1980-06-01  7.8424
# 90  1980-07-01  7.7664
# 91  1980-08-01  7.7824
# 92  1980-09-01  7.7495
# 93  1980-10-01  7.7323
# 94  1980-11-01  7.7712
# 95  1980-12-01  7.9314

# %%
plt.figure(figsize=(15, 5))
plt.title("Dollar Vs Rupess in year 1980")
plt.scatter(x.DATE, x.EXINUS, marker='v', color='red', linewidths=10)
plt.plot(x.DATE, x.EXINUS)
plt.xlabel("Dated")
plt.ylabel("1$= Rs")
plt.plot()
plt.show()

# %%
x=df.iloc[96:108]

# %%
x
# Out:
#            DATE  EXINUS
# 96   1981-01-01  7.9576
# 97   1981-02-01  8.2211
# 98   1981-03-01  8.2432
# 99   1981-04-01  8.2918
# 100  1981-05-01  8.4045
# 101  1981-06-01  8.5564
# 102  1981-07-01  8.9065
# 103  1981-08-01  9.0605
# 104  1981-09-01  9.1152
# 105  1981-10-01  9.1348
# 106  1981-11-01  9.1350
# 107  1981-12-01  9.1305

# %%
plt.figure(figsize=(15, 5))
plt.title("Dollar Vs Rupess in year 1981")
plt.scatter(x.DATE, x.EXINUS, marker='v', color='red', linewidths=10)
plt.plot(x.DATE, x.EXINUS)
plt.xlabel("Dated")
plt.ylabel("1$= Rs")
plt.plot()
plt.show()

# %%
x=df.iloc[108:120]

# %%
x
# Out:
#            DATE  EXINUS
# 108  1982-01-01  9.1525
# 109  1982-02-01  9.2144
# 110  1982-03-01  9.2935
# 111  1982-04-01  9.3923
# 112  1982-05-01  9.2965
# 113  1982-06-01  9.4668
# 114  1982-07-01  9.5633
# 115  1982-08-01  9.5741
# 116  1982-09-01  9.6495
# 117  1982-10-01  9.7005
# 118  1982-11-01  9.7968
# 119  1982-12-01  9.6926

# %%
plt.figure(figsize=(15, 5))
plt.title("Dollar Vs Rupess in year 1982")
plt.scatter(x.DATE, x.EXINUS, marker='v', color='red', linewidths=10)
plt.plot(x.DATE, x.EXINUS)
plt.xlabel("Dated")
plt.ylabel("1$= Rs")
plt.plot()
plt.show()

# %%
x=df.iloc[120:132]

# %%
x
# Out:
#            DATE   EXINUS
# 120  1983-01-01   9.7938
# 121  1983-02-01   9.9184
# 122  1983-03-01   9.9652
# 123  1983-04-01   9.9824
# 124  1983-05-01   9.9895
# 125  1983-06-01  10.0491
# 126  1983-07-01  10.0875
# 127  1983-08-01  10.1874
# 128  1983-09-01  10.2005
# 129  1983-10-01  10.2290
# 130  1983-11-01  10.3784
# 131  1983-12-01  10.4895

# %%
plt.figure(figsize=(15, 5))
plt.title("Dollar Vs Rupess in year 1983")
plt.scatter(x.DATE, x.EXINUS, marker='v', color='red', linewidths=10)
plt.plot(x.DATE, x.EXINUS)
plt.xlabel("Dated")
plt.ylabel("1$= Rs")
plt.plot()
plt.show()

# %%
x=df.iloc[132:144]

# %%
x
# Out:
#            DATE   EXINUS
# 132  1984-01-01  10.7152
# 133  1984-02-01  10.7437
# 134  1984-03-01  10.7145
# 135  1984-04-01  10.8200
# 136  1984-05-01  11.0168
# 137  1984-06-01  11.0638
# 138  1984-07-01  11.3714
# 139  1984-08-01  11.5561
# 140  1984-09-01  11.8584
# 141  1984-10-01  12.0268
# 142  1984-11-01  12.0784
# 143  1984-12-01  12.2925

# %%
plt.figure(figsize=(15, 5))
plt.title("Dollar Vs Rupess in year 1984")
plt.scatter(x.DATE, x.EXINUS, marker='v', color='red', linewidths=10)
plt.plot(x.DATE, x.EXINUS)
plt.xlabel("Dated")
plt.ylabel("1$= Rs")
plt.plot()
plt.show()

# %%
x=df.iloc[144:156]

# %%
x
# Out:
#            DATE   EXINUS
# 144  1985-01-01  12.6119
# 145  1985-02-01  12.9217
# 146  1985-03-01  12.8614
# 147  1985-04-01  12.4005
# 148  1985-05-01  12.5005
# 149  1985-06-01  12.4405
# 150  1985-07-01  12.0314
# 151  1985-08-01  11.8977
# 152  1985-09-01  12.1255
# 153  1985-10-01  12.0332
# 154  1985-11-01  12.1011
# 155  1985-12-01  12.1524

# %%
plt.figure(figsize=(15, 5))
plt.title("Dollar Vs Rupess in year 1985")
plt.scatter(x.DATE, x.EXINUS, marker='v', color='red', linewidths=10)
plt.plot(x.DATE, x.EXINUS)
plt.xlabel("Dated")
plt.ylabel("1$= Rs")
plt.plot()
plt.show()

# %%
x=df.iloc[156:168]

# %%
x
# Out:
#            DATE   EXINUS
# 156  1986-01-01  12.2433
# 157  1986-02-01  12.3700
# 158  1986-03-01  12.2890
# 159  1986-04-01  12.3932
# 160  1986-05-01  12.4657
# 161  1986-06-01  12.5986
# 162  1986-07-01  12.5077
# 163  1986-08-01  12.5667
# 164  1986-09-01  12.6757
# 165  1986-10-01  12.8486
# 166  1986-11-01  13.0761
# 167  1986-12-01  13.1486

# %%
plt.figure(figsize=(15, 5))
plt.title("Dollar Vs Rupess in year 1986")
plt.scatter(x.DATE, x.EXINUS, marker='v', color='red', linewidths=10)
plt.plot(x.DATE, x.EXINUS)
plt.xlabel("Dated")
plt.ylabel("1$= Rs")
plt.plot()
plt.show()

# %%
x=df.iloc[168:180]

# %%
x
# Out:
#            DATE   EXINUS
# 168  1987-01-01  13.0295
# 169  1987-02-01  13.0621
# 170  1987-03-01  12.9236
# 171  1987-04-01  12.8145
# 172  1987-05-01  12.6660
# 173  1987-06-01  12.8368
# 174  1987-07-01  13.0126
# 175  1987-08-01  13.0852
# 176  1987-09-01  12.9933
# 177  1987-10-01  13.0429
# 178  1987-11-01  12.9721
# 179  1987-12-01  12.9345

# %%
plt.figure(figsize=(15, 5))
plt.title("Dollar Vs Rupess in year 1987")
plt.scatter(x.DATE, x.EXINUS, marker='v', color='red', linewidths=10)
plt.plot(x.DATE, x.EXINUS)
plt.xlabel("Dated")
plt.ylabel("1$= Rs")
plt.plot()
plt.show()

# %%
x=df.iloc[180:192]

# %%
x
# Out:
#            DATE   EXINUS
# 180  1988-01-01  13.0395
# 181  1988-02-01  13.0650
# 182  1988-03-01  12.9791
# 183  1988-04-01  13.1576
# 184  1988-05-01  13.3157
# 185  1988-06-01  13.7859
# 186  1988-07-01  14.0795
# 187  1988-08-01  14.2170
# 188  1988-09-01  14.4895
# 189  1988-10-01  14.7200
# 190  1988-11-01  14.9660
# 191  1988-12-01  15.0190

# %%
plt.figure(figsize=(15, 5))
plt.title("Dollar Vs Rupess in year 1988")
plt.scatter(x.DATE, x.EXINUS, marker='v', color='red', linewidths=10)
plt.plot(x.DATE, x.EXINUS)
plt.xlabel("Dated")
plt.ylabel("1$= Rs")
plt.plot()
plt.show()

# %%
x=df.iloc[192:204]

# %%
x
# Out:
#            DATE   EXINUS
# 192  1989-01-01  15.0925
# 193  1989-02-01  15.2405
# 194  1989-03-01  15.4674
# 195  1989-04-01  15.7180
# 196  1989-05-01  16.1018
# 197  1989-06-01  16.4195
# 198  1989-07-01  16.4160
# 199  1989-08-01  16.6091
# 200  1989-09-01  16.7450
# 201  1989-10-01  16.8190
# 202  1989-11-01  16.9248
# 203  1989-12-01  16.9320

# %%
plt.figure(figsize=(15, 5))
plt.title("Dollar Vs Rupess in year 1989")
plt.scatter(x.DATE, x.EXINUS, marker='v', color='red', linewidths=10)
plt.plot(x.DATE, x.EXINUS)
plt.xlabel("Dated")
plt.ylabel("1$= Rs")
plt.plot()
plt.show()

# %%
x=df.iloc[204:216]

# %%
x
# Out:
#            DATE   EXINUS
# 204  1990-01-01  16.9633
# 205  1990-02-01  16.9895
# 206  1990-03-01  17.1164
# 207  1990-04-01  17.2943
# 208  1990-05-01  17.3245
# 209  1990-06-01  17.4210
# 210  1990-07-01  17.4119
# 211  1990-08-01  17.3465
# 212  1990-09-01  17.8595
# 213  1990-10-01  18.0736
# 214  1990-11-01  18.0975
# 215  1990-12-01  18.1272

# %%
plt.figure(figsize=(15, 5))
plt.title("Dollar Vs Rupess in year 1990")
plt.scatter(x.DATE, x.EXINUS, marker='v', color='red', linewidths=10)
plt.plot(x.DATE, x.EXINUS)
plt.xlabel("Dated")
plt.ylabel("1$= Rs")
plt.plot()
plt.show()

# %%
x=df.iloc[216:228]

# %%
x
# Out:
#            DATE   EXINUS
# 216  1991-01-01  18.3390
# 217  1991-02-01  18.8600
# 218  1991-03-01  19.2429
# 219  1991-04-01  19.9064
# 220  1991-05-01  20.5186
# 221  1991-06-01  21.0620
# 222  1991-07-01  25.6127
# 223  1991-08-01  25.8457
# 224  1991-09-01  25.8335
# 225  1991-10-01  25.7973
# 226  1991-11-01  25.8021
# 227  1991-12-01  25.8180

# %%
plt.figure(figsize=(15, 5))
plt.title("Dollar Vs Rupess in year 1991")
plt.scatter(x.DATE, x.EXINUS, marker='v', color='red', linewidths=10)
plt.plot(x.DATE, x.EXINUS)
plt.xlabel("Dated")
plt.ylabel("1$= Rs")
plt.plot()
plt.show()

# %%
x=df.iloc[228:240]

# %%
x
# Out:
#            DATE   EXINUS
# 228  1992-01-01  25.8629
# 229  1992-02-01  25.9921
# 230  1992-03-01  28.3777
# 231  1992-04-01  28.8962
# 232  1992-05-01  28.5415
# 233  1992-06-01  28.5186
# 234  1992-07-01  28.5639
# 235  1992-08-01  28.4635
# 236  1992-09-01  28.4757
# 237  1992-10-01  28.4767
# 238  1992-11-01  28.4737
# 239  1992-12-01  28.9786

# %%
plt.figure(figsize=(15, 5))
plt.title("Dollar Vs Rupess in year 1992")
plt.scatter(x.DATE, x.EXINUS, marker='v', color='red', linewidths=10)
plt.plot(x.DATE, x.EXINUS)
plt.xlabel("Dated")
plt.ylabel("1$= Rs")
plt.plot()
plt.show()

# %%
x=df.iloc[240:252]

# %%
x
# Out:
#            DATE   EXINUS
# 240  1993-01-01  29.0432
# 241  1993-02-01  30.0421
# 242  1993-03-01  31.9391
# 243  1993-04-01  31.6095
# 244  1993-05-01  31.6125
# 245  1993-06-01  31.6682
# 246  1993-07-01  31.6000
# 247  1993-08-01  31.6123
# 248  1993-09-01  31.5776
# 249  1993-10-01  31.5050
# 250  1993-11-01  31.4335
# 251  1993-12-01  31.4400

# %%
plt.figure(figsize=(15, 5))
plt.title("Dollar Vs Rupess in year 1993")
plt.scatter(x.DATE, x.EXINUS, marker='v', color='red', linewidths=10)
plt.plot(x.DATE, x.EXINUS)
plt.xlabel("Dated")
plt.ylabel("1$= Rs")
plt.plot()
plt.show()

# %%
x=df.iloc[252:264]

# %%
x
# Out:
#            DATE   EXINUS
# 252  1994-01-01  31.4400
# 253  1994-02-01  31.4489
# 254  1994-03-01  31.4147
# 255  1994-04-01  31.3914
# 256  1994-05-01  31.3754
# 257  1994-06-01  31.3845
# 258  1994-07-01  31.3764
# 259  1994-08-01  31.3727
# 260  1994-09-01  31.3723
# 261  1994-10-01  31.3726
# 262  1994-11-01  31.3940
# 263  1994-12-01  31.3894

# %%
plt.figure(figsize=(15, 5))
plt.title("Dollar Vs Rupess in year 1994")
plt.scatter(x.DATE, x.EXINUS, marker='v', color='red', linewidths=10)
plt.plot(x.DATE, x.EXINUS)
plt.xlabel("Dated")
plt.ylabel("1$= Rs")
plt.plot()
plt.show()

# %%
x=df.iloc[264:276]

# %%
x
# Out:
#            DATE   EXINUS
# 264  1995-01-01  31.3736
# 265  1995-02-01  31.3795
# 266  1995-03-01  31.5865
# 267  1995-04-01  31.4073
# 268  1995-05-01  31.4179
# 269  1995-06-01  31.4037
# 270  1995-07-01  31.3853
# 271  1995-08-01  31.5923
# 272  1995-09-01  33.3098
# 273  1995-10-01  34.6564
# 274  1995-11-01  34.7100
# 275  1995-12-01  34.9663

# %%
plt.figure(figsize=(15, 5))
plt.title("Dollar Vs Rupess in year 1995")
plt.scatter(x.DATE, x.EXINUS, marker='v', color='red', linewidths=10)
plt.plot(x.DATE, x.EXINUS)
plt.xlabel("Dated")
plt.ylabel("1$= Rs")
plt.plot()
plt.show()

# %%
x=df.iloc[276:288]

# %%
x
# Out:
#            DATE   EXINUS
# 276  1996-01-01  35.8117
# 277  1996-02-01  36.5945
# 278  1996-03-01  34.4852
# 279  1996-04-01  34.3195
# 280  1996-05-01  35.0250
# 281  1996-06-01  35.0995
# 282  1996-07-01  35.6673
# 283  1996-08-01  35.8000
# 284  1996-09-01  35.8700
# 285  1996-10-01  35.8036
# 286  1996-11-01  35.8392
# 287  1996-12-01  35.8815

# %%
plt.figure(figsize=(15, 5))
plt.title("Dollar Vs Rupess in year 1996")
plt.scatter(x.DATE, x.EXINUS, marker='v', color='red', linewidths=10)
plt.plot(x.DATE, x.EXINUS)
plt.xlabel("Dated")
plt.ylabel("1$= Rs")
plt.plot()
plt.show()

# %%
x=df.iloc[288:300]

# %%
x
# Out:
#            DATE   EXINUS
# 288  1997-01-01  35.9037
# 289  1997-02-01  35.8905
# 290  1997-03-01  35.8848
# 291  1997-04-01  35.8281
# 292  1997-05-01  35.8248
# 293  1997-06-01  35.8202
# 294  1997-07-01  35.7474
# 295  1997-08-01  36.0085
# 296  1997-09-01  36.4756
# 297  1997-10-01  36.3020
# 298  1997-11-01  37.2889
# 299  1997-12-01  39.4000

# %%
plt.figure(figsize=(15, 5))
plt.title("Dollar Vs Rupess in year 1997")
plt.scatter(x.DATE, x.EXINUS, marker='v', color='red', linewidths=10)
plt.plot(x.DATE, x.EXINUS)
plt.xlabel("Dated")
plt.ylabel("1$= Rs")
plt.plot()
plt.show()

# %%
x=df.iloc[300:312]

# %%
x
# Out:
#            DATE   EXINUS
# 300  1998-01-01  39.3910
# 301  1998-02-01  39.0079
# 302  1998-03-01  39.5686
# 303  1998-04-01  39.7029
# 304  1998-05-01  40.4687
# 305  1998-06-01  42.3668
# 306  1998-07-01  42.6118
# 307  1998-08-01  42.8429
# 308  1998-09-01  42.5790
# 309  1998-10-01  42.3943
# 310  1998-11-01  42.4284
# 311  1998-12-01  42.5909

# %%
plt.figure(figsize=(15, 5))
plt.title("Dollar Vs Rupess in year 1998")
plt.scatter(x.DATE, x.EXINUS, marker='v', color='red', linewidths=10)
plt.plot(x.DATE, x.EXINUS)
plt.xlabel("Dated")
plt.ylabel("1$= Rs")
plt.plot()
plt.show()

# %%
x=df.iloc[312:324]

# %%
x
# Out:
#            DATE   EXINUS
# 312  1999-01-01  42.5453
# 313  1999-02-01  42.5316
# 314  1999-03-01  42.5161
# 315  1999-04-01  42.7968
# 316  1999-05-01  42.8590
# 317  1999-06-01  43.2127
# 318  1999-07-01  43.3567
# 319  1999-08-01  43.5032
# 320  1999-09-01  43.5981
# 321  1999-10-01  43.5528
# 322  1999-11-01  43.4580
# 323  1999-12-01  43.5239

# %%
plt.figure(figsize=(15, 5))
plt.title("Dollar Vs Rupess in year 1999")
plt.scatter(x.DATE, x.EXINUS, marker='v', color='red', linewidths=10)
plt.plot(x.DATE, x.EXINUS)
plt.xlabel("Dated")
plt.ylabel("1$= Rs")
plt.plot()
plt.show()

# %%
x=df.iloc[324:336]

# %%
x
# Out:
#            DATE   EXINUS
# 324  2000-01-01  43.5895
# 325  2000-02-01  43.6540
# 326  2000-03-01  43.6383
# 327  2000-04-01  43.6847
# 328  2000-05-01  44.0759
# 329  2000-06-01  44.7605
# 330  2000-07-01  44.8405
# 331  2000-08-01  45.7687
# 332  2000-09-01  45.9680
# 333  2000-10-01  46.4252
# 334  2000-11-01  46.8214
# 335  2000-12-01  46.7845

# %%
plt.figure(figsize=(15, 5))
plt.title("Dollar Vs Rupess in year 2000")
plt.scatter(x.DATE, x.EXINUS, marker='v', color='red', linewidths=10)
plt.plot(x.DATE, x.EXINUS)
plt.xlabel("Dated")
plt.ylabel("1$= Rs")
plt.plot()
plt.show()

# %%
x=df.iloc[336:348]

# %%
x
# Out:
#            DATE   EXINUS
# 336  2001-01-01  46.6138
# 337  2001-02-01  46.5616
# 338  2001-03-01  46.6532
# 339  2001-04-01  46.7886
# 340  2001-05-01  46.9473
# 341  2001-06-01  47.0424
# 342  2001-07-01  47.1781
# 343  2001-08-01  47.1665
# 344  2001-09-01  47.7511
# 345  2001-10-01  48.0514
# 346  2001-11-01  48.0430
# 347  2001-12-01  47.9345

# %%
plt.figure(figsize=(15, 5))
plt.title("Dollar Vs Rupess in year 2001")
plt.scatter(x.DATE, x.EXINUS, marker='v', color='red', linewidths=10)
plt.plot(x.DATE, x.EXINUS)
plt.xlabel("Dated")
plt.ylabel("1$= Rs")
plt.plot()
plt.show()

# %%
x=df.iloc[348:360]

# %%
x
# Out:
#            DATE   EXINUS
# 348  2002-01-01  48.3533
# 349  2002-02-01  48.7168
# 350  2002-03-01  48.7667
# 351  2002-04-01  48.9386
# 352  2002-05-01  49.0168
# 353  2002-06-01  48.9840
# 354  2002-07-01  48.7877
# 355  2002-08-01  48.6150
# 356  2002-09-01  48.4625
# 357  2002-10-01  48.3882
# 358  2002-11-01  48.2853
# 359  2002-12-01  48.1495

# %%
plt.figure(figsize=(15, 5))
plt.title("Dollar Vs Rupess in year 2002")
plt.scatter(x.DATE, x.EXINUS, marker='v', color='red', linewidths=10)
plt.plot(x.DATE, x.EXINUS)
plt.xlabel("Dated")
plt.ylabel("1$= Rs")
plt.plot()
plt.show()

# %%
x=df.iloc[360:372]

# %%
x
# Out:
#            DATE   EXINUS
# 360  2003-01-01  47.9571
# 361  2003-02-01  47.7474
# 362  2003-03-01  47.6767
# 363  2003-04-01  47.3909
# 364  2003-05-01  47.1100
# 365  2003-06-01  46.6995
# 366  2003-07-01  46.2200
# 367  2003-08-01  45.9557
# 368  2003-09-01  45.8467
# 369  2003-10-01  45.4036
# 370  2003-11-01  45.5544
# 371  2003-12-01  45.5741

# %%
plt.figure(figsize=(15, 5))
plt.title("Dollar Vs Rupess in year 2003")
plt.scatter(x.DATE, x.EXINUS, marker='v', color='red', linewidths=10)
plt.plot(x.DATE, x.EXINUS)
plt.xlabel("Dated")
plt.ylabel("1$= Rs")
plt.plot()
plt.show()

# %%
x=df.iloc[372:384]

# %%
x
# Out:
#            DATE   EXINUS
# 372  2004-01-01  45.4560
# 373  2004-02-01  45.2726
# 374  2004-03-01  44.9693
# 375  2004-04-01  43.8918
# 376  2004-05-01  45.1755
# 377  2004-06-01  45.5027
# 378  2004-07-01  46.0557
# 379  2004-08-01  46.3220
# 380  2004-09-01  46.0548
# 381  2004-10-01  45.7355
# 382  2004-11-01  45.0325
# 383  2004-12-01  43.8470

# %%
plt.figure(figsize=(15, 5))
plt.title("Dollar Vs Rupess in year 2004")
plt.scatter(x.DATE, x.EXINUS, marker='v', color='red', linewidths=10)
plt.plot(x.DATE, x.EXINUS)
plt.xlabel("Dated")
plt.ylabel("1$= Rs")
plt.plot()
plt.show()

# %%
x=df.iloc[384:396]

# %%
x
# Out:
#            DATE   EXINUS
# 384  2005-01-01  43.6150
# 385  2005-02-01  43.5758
# 386  2005-03-01  43.5861
# 387  2005-04-01  43.6419
# 388  2005-05-01  43.4095
# 389  2005-06-01  43.5245
# 390  2005-07-01  43.4340
# 391  2005-08-01  43.5500
# 392  2005-09-01  43.8462
# 393  2005-10-01  44.7575
# 394  2005-11-01  45.6315
# 395  2005-12-01  45.5633

# %%
plt.figure(figsize=(15, 5))
plt.title("Dollar Vs Rupess in year 2005")
plt.scatter(x.DATE, x.EXINUS, marker='v', color='red', linewidths=10)
plt.plot(x.DATE, x.EXINUS)
plt.xlabel("Dated")
plt.ylabel("1$= Rs")
plt.plot()
plt.show()

# %%
x=df.iloc[396:408]

# %%
x
# Out:
#            DATE   EXINUS
# 396  2006-01-01  44.2010
# 397  2006-02-01  44.2300
# 398  2006-03-01  44.3378
# 399  2006-04-01  44.8245
# 400  2006-05-01  45.1959
# 401  2006-06-01  45.8886
# 402  2006-07-01  46.3675
# 403  2006-08-01  46.4461
# 404  2006-09-01  46.0105
# 405  2006-10-01  45.3552
# 406  2006-11-01  44.7257
# 407  2006-12-01  44.4835

# %%
plt.figure(figsize=(15, 5))
plt.title("Dollar Vs Rupess in year 2006")
plt.scatter(x.DATE, x.EXINUS, marker='v', color='red', linewidths=10)
plt.plot(x.DATE, x.EXINUS)
plt.xlabel("Dated")
plt.ylabel("1$= Rs")
plt.plot()
plt.show()

# %%
x=df.iloc[408:420]

# %%
x
# Out:
#            DATE   EXINUS
# 408  2007-01-01  44.2062
# 409  2007-02-01  44.0195
# 410  2007-03-01  43.7936
# 411  2007-04-01  42.0176
# 412  2007-05-01  40.5686
# 413  2007-06-01  40.5905
# 414  2007-07-01  40.2738
# 415  2007-08-01  40.6791
# 416  2007-09-01  40.1735
# 417  2007-10-01  39.3661
# 418  2007-11-01  39.3267
# 419  2007-12-01  39.3750

# %%
plt.figure(figsize=(15, 5))
plt.title("Dollar Vs Rupess in year 2007")
plt.scatter(x.DATE, x.EXINUS, marker='v', color='red', linewidths=10)
plt.plot(x.DATE, x.EXINUS)
plt.xlabel("Dated")
plt.ylabel("1$= Rs")
plt.plot()
plt.show()

# %%
x=df.iloc[420:432]

# %%
x
# Out:
#            DATE   EXINUS
# 420  2008-01-01  39.2676
# 421  2008-02-01  39.6735
# 422  2008-03-01  40.1452
# 423  2008-04-01  39.9668
# 424  2008-05-01  42.0019
# 425  2008-06-01  42.7633
# 426  2008-07-01  42.7027
# 427  2008-08-01  42.9057
# 428  2008-09-01  45.5300
# 429  2008-10-01  48.6155
# 430  2008-11-01  48.8517
# 431  2008-12-01  48.5132

# %%
plt.figure(figsize=(15, 5))
plt.title("Dollar Vs Rupess in year 2008")
plt.scatter(x.DATE, x.EXINUS, marker='v', color='red', linewidths=10)
plt.plot(x.DATE, x.EXINUS)
plt.xlabel("Dated")
plt.ylabel("1$= Rs")
plt.plot()
plt.show()

# %%
x=df.iloc[432:444]

# %%
x
# Out:
#            DATE   EXINUS
# 432  2009-01-01  48.6995
# 433  2009-02-01  49.2484
# 434  2009-03-01  51.1291
# 435  2009-04-01  49.9655
# 436  2009-05-01  48.5100
# 437  2009-06-01  47.6736
# 438  2009-07-01  48.3624
# 439  2009-08-01  48.2426
# 440  2009-09-01  48.2924
# 441  2009-10-01  46.6524
# 442  2009-11-01  46.5305
# 443  2009-12-01  46.5273

# %%
plt.figure(figsize=(15, 5))
plt.title("Dollar Vs Rupess in year 2009")
plt.scatter(x.DATE, x.EXINUS, marker='v', color='red', linewidths=10)
plt.plot(x.DATE, x.EXINUS)
plt.xlabel("Dated")
plt.ylabel("1$= Rs")
plt.plot()
plt.show()

# %%
x=df.iloc[444:456]

# %%
x
# Out:
#            DATE   EXINUS
# 444  2010-01-01  45.8944
# 445  2010-02-01  46.2732
# 446  2010-03-01  45.4509
# 447  2010-04-01  44.4440
# 448  2010-05-01  45.7690
# 449  2010-06-01  46.4983
# 450  2010-07-01  46.7617
# 451  2010-08-01  46.4605
# 452  2010-09-01  45.8729
# 453  2010-10-01  44.3540
# 454  2010-11-01  44.9315
# 455  2010-12-01  45.1000

# %%
plt.figure(figsize=(15, 5))
plt.title("Dollar Vs Rupess in year 2010")
plt.scatter(x.DATE, x.EXINUS, marker='v', color='red', linewidths=10)
plt.plot(x.DATE, x.EXINUS)
plt.xlabel("Dated")
plt.ylabel("1$= Rs")
plt.plot()
plt.show()

# %%
x=df.iloc[456:468]

# %%
x
# Out:
#            DATE   EXINUS
# 456  2011-01-01  45.3750
# 457  2011-02-01  45.3795
# 458  2011-03-01  44.9143
# 459  2011-04-01  44.3010
# 460  2011-05-01  44.9024
# 461  2011-06-01  44.8109
# 462  2011-07-01  44.3960
# 463  2011-08-01  45.3135
# 464  2011-09-01  47.6905
# 465  2011-10-01  49.2020
# 466  2011-11-01  50.6785
# 467  2011-12-01  52.3824

# %%
plt.figure(figsize=(15, 5))
plt.title("Dollar Vs Rupess in year 2011")
plt.scatter(x.DATE, x.EXINUS, marker='v', color='red', linewidths=10)
plt.plot(x.DATE, x.EXINUS)
plt.xlabel("Dated")
plt.ylabel("1$= Rs")
plt.plot()
plt.show()

# %%
x=df.iloc[468:480]

# %%
x
# Out:
#            DATE   EXINUS
# 468  2012-01-01  51.0015
# 469  2012-02-01  49.1812
# 470  2012-03-01  50.3635
# 471  2012-04-01  51.6900
# 472  2012-05-01  54.3314
# 473  2012-06-01  55.9424
# 474  2012-07-01  55.4248
# 475  2012-08-01  55.4935
# 476  2012-09-01  54.3500
# 477  2012-10-01  53.0995
# 478  2012-11-01  54.7845
# 479  2012-12-01  54.6470

# %%
plt.figure(figsize=(15, 5))
plt.title("Dollar Vs Rupess in year 2012")
plt.scatter(x.DATE, x.EXINUS, marker='v', color='red', linewidths=10)
plt.plot(x.DATE, x.EXINUS)
plt.xlabel("Dated")
plt.ylabel("1$= Rs")
plt.plot()
plt.show()

# %%
x=df.iloc[480:492]

# %%
x
# Out:
#            DATE   EXINUS
# 480  2013-01-01  54.2290
# 481  2013-02-01  53.8079
# 482  2013-03-01  54.4229
# 483  2013-04-01  54.3236
# 484  2013-05-01  54.9845
# 485  2013-06-01  58.3835
# 486  2013-07-01  59.7609
# 487  2013-08-01  62.8109
# 488  2013-09-01  63.6480
# 489  2013-10-01  61.6059
# 490  2013-11-01  62.5179
# 491  2013-12-01  61.8110

# %%
plt.figure(figsize=(15, 5))
plt.title("Dollar Vs Rupess in year 2013")
plt.scatter(x.DATE, x.EXINUS, marker='v', color='red', linewidths=10)
plt.plot(x.DATE, x.EXINUS)
plt.xlabel("Dated")
plt.ylabel("1$= Rs")
plt.plot()
plt.show()

# %%
x=df.iloc[492:504]

# %%
x
# Out:
#            DATE   EXINUS
# 492  2014-01-01  62.1057
# 493  2014-02-01  62.1642
# 494  2014-03-01  60.9476
# 495  2014-04-01  60.3464
# 496  2014-05-01  59.2843
# 497  2014-06-01  59.7367
# 498  2014-07-01  60.0956
# 499  2014-08-01  60.8738
# 500  2014-09-01  60.8976
# 501  2014-10-01  61.3668
# 502  2014-11-01  61.6828
# 503  2014-12-01  62.7071

# %%
plt.figure(figsize=(15, 5))
plt.title("Dollar Vs Rupess in year 2014")
plt.scatter(x.DATE, x.EXINUS, marker='v', color='red', linewidths=10)
plt.plot(x.DATE, x.EXINUS)
plt.xlabel("Dated")
plt.ylabel("1$= Rs")
plt.plot()
plt.show()

# %%
x=df.iloc[504:516]

# %%
x
# Out:
#            DATE   EXINUS
# 504  2015-01-01  62.1300
# 505  2015-02-01  61.9905
# 506  2015-03-01  62.4805
# 507  2015-04-01  62.6414
# 508  2015-05-01  63.7150
# 509  2015-06-01  63.7809
# 510  2015-07-01  63.6045
# 511  2015-08-01  65.0971
# 512  2015-09-01  66.1667
# 513  2015-10-01  65.0262
# 514  2015-11-01  66.1000
# 515  2015-12-01  66.5023

# %%
plt.figure(figsize=(15, 5))
plt.title("Dollar Vs Rupess in year 2015")
plt.scatter(x.DATE, x.EXINUS, marker='v', color='red', linewidths=10)
plt.plot(x.DATE, x.EXINUS)
plt.xlabel("Dated")
plt.ylabel("1$= Rs")
plt.plot()
plt.show()

# %%
x=df.iloc[516:528]

# %%
x
# Out:
#            DATE   EXINUS
# 516  2016-01-01  67.3332
# 517  2016-02-01  68.2395
# 518  2016-03-01  66.8909
# 519  2016-04-01  66.4219
# 520  2016-05-01  66.8895
# 521  2016-06-01  67.2655
# 522  2016-07-01  67.1580
# 523  2016-08-01  66.9035
# 524  2016-09-01  66.7138
# 525  2016-10-01  66.7415
# 526  2016-11-01  67.6395
# 527  2016-12-01  67.8052

# %%
plt.figure(figsize=(15, 5))
plt.title("Dollar Vs Rupess in year 2016")
plt.scatter(x.DATE, x.EXINUS, marker='v', color='red', linewidths=10)
plt.plot(x.DATE, x.EXINUS)
plt.xlabel("Dated")
plt.ylabel("1$= Rs")
plt.plot()
plt.show()

# %%
x=df.iloc[528:540]

# %%
x
# Out:
#            DATE   EXINUS
# 528  2017-01-01  68.0474
# 529  2017-02-01  66.9726
# 530  2017-03-01  65.8009
# 531  2017-04-01  64.5360
# 532  2017-05-01  64.4195
# 533  2017-06-01  64.4482
# 534  2017-07-01  64.4240
# 535  2017-08-01  63.9683
# 536  2017-09-01  64.4775
# 537  2017-10-01  65.0357
# 538  2017-11-01  64.8435
# 539  2017-12-01  64.2445

# %%
plt.figure(figsize=(15, 5))
plt.title("Dollar Vs Rupess in year 2017")
plt.scatter(x.DATE, x.EXINUS, marker='v', color='red', linewidths=10)
plt.plot(x.DATE, x.EXINUS)
plt.xlabel("Dated")
plt.ylabel("1$= Rs")
plt.plot()
plt.show()

# %%
x=df.iloc[540:552]

# %%
x
# Out:
#            DATE   EXINUS
# 540  2018-01-01  63.6452
# 541  2018-02-01  64.4300
# 542  2018-03-01  65.0455
# 543  2018-04-01  65.6729
# 544  2018-05-01  67.5100
# 545  2018-06-01  67.7900
# 546  2018-07-01  68.6867
# 547  2018-08-01  69.6317
# 548  2018-09-01  71.5800

# %%
plt.figure(figsize=(15, 5))
plt.title("Dollar Vs Rupess in year 2018")
plt.scatter(x.DATE, x.EXINUS, marker='v', color='red', linewidths=10)
plt.plot(x.DATE, x.EXINUS)
plt.xlabel("Dated")
plt.ylabel("1$= Rs")
plt.plot()
plt.show()
